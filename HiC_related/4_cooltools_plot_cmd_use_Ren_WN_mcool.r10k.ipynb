# %%
# ref： https://cooltools.readthedocs.io/en/latest/notebooks/viz.html

# %%
import os 
print(os.getcwd())
os.chdir("/data1/sunwenju/projects_on_940xa/2024041703_mESC_HiC_use_pairtools_cooler_pipeline/")
print(os.getcwd())

# %%
! find . -name *rep12.merged.1k.zoomify.mcool

# %%
ren_wt_rep12_mcool = "./Ren_WT/Ren_mESC_WT_HiC.rep12.merged.1k.zoomify.mcool"
ren_iaa_rep12_mcool = "./Ren_IAA/Ren_mESC_IAA_HiC.rep12.merged.1k.zoomify.mcool"
wn_bpk25_rep12_mcool = "./WN_BPK25/WN_mESC_BPK25_HiC.rep12.merged.1k.zoomify.mcool"

# %%
import cooler
# to print which resolutions are stored in the mcool, use list_coolers
cooler.fileops.list_coolers(ren_wt_rep12_mcool)

# %%
### to load a cooler with a specific resolution use the following syntax:
ren_wt_rep12_mcool_r10k = cooler.Cooler(f'{ren_wt_rep12_mcool}::resolutions/10000')
ren_iaa_rep12_mcool_r10k = cooler.Cooler(f'{ren_iaa_rep12_mcool}::resolutions/10000')
wn_bpk25_rep12_mcool_r10k = cooler.Cooler(f'{wn_bpk25_rep12_mcool}::resolutions/10000')

# %% [markdown]
# # rep12 merged mcool r10k plot

# %% [markdown]
# ## r10k Fig2A

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x', rotation=45)

chromsome = "chr1"
start = 16_500_000
end = 17_900_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig2A_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig2A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig2A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Fig2B

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr9"
start = 13_790_000
end = 15_100_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig2B_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig2B_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig2B_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Fig3A

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr8"
start = 88_500_000
end = 94_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig3A_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig3A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig3A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Fig3C

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr8"
start = 119_000_000
end = 120_700_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig3C_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig3C_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig3C_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Fig3E

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr1"
start = 9_800_000
end = 14_600_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig3E_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig3E_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig3E_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Fig5A

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chrX"
start = 100_400_000
end = 103_400_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig5A_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1000, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_Fig5A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig5A_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chrX"
start = 100_470_000
end = 100_660_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_Fig5A_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1500, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1500, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1500, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)

plt.savefig("Nora_Fig5A_use_Ren_WT_IAA_WN_BPK25.zoomIn.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_Fig5A_use_Ren_WT_IAA_WN_BPK25.zoomIn.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k FigS3I

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr3"
start = 39_900_000
end = 42_900_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_FigS3I_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_FigS3I_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_FigS3I_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k FigS3J

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr14"
start =109_400_000
end = 111_900_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=4, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nora_FigS3J_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=400, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("Nora_FigS3J_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("Nora_FigS3J_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Malat1 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr19"
start = 5_000_000
end = 6_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Malat1_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1200, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1200, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=1200, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Malat1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Malat1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Myc flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr15"
start = 61_000_000
end = 63_000_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Myc_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Myc_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Myc_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Nanog flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr6"
start = 121_500_000
end = 123_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Nanog_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=900, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=900, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=900, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Nanog_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Nanog_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Pou5f1 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr17"
start = 34_500_000
end = 36_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Pou5f1_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=800, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Pou5f1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Pou5f1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Sox2 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr3"
start = 33_500_000
end = 35_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Sox2_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Sox2_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Sox2_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Pax6 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr2"
start = 104_500_000
end = 106_500_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Pax6_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=500, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Pax6_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Pax6_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Sox1 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr8"
start = 11_000_000
end = 13_000_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Sox1_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=600, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Sox1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Sox1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %% [markdown]
# ## r10k Zic1 flank

# %%
### plot data in fall heatmap
import matplotlib
import matplotlib.pyplot as plt
import cooltools.lib.plotting
from cooltools.lib.numutils import adaptive_coarsegrain, interp_nan
# 设置为可编辑字体，默认的字体在AI中打开是路径
matplotlib.rcParams['pdf.fonttype'] = 42
# to plot ticks in terms of megabases we use the EngFormatter
# https://matplotlib.org/gallery/api/engineering_formatter.html

from matplotlib.ticker import EngFormatter
bp_formatter = EngFormatter('b')
def format_ticks(ax, x=True, y=True, rotate=True):
    if y:
        ax.yaxis.set_major_formatter(bp_formatter)
    if x:
        ax.xaxis.set_major_formatter(bp_formatter)
        ax.xaxis.tick_bottom()
    if rotate:
        ax.tick_params(axis='x',rotation=45)

chromsome = "chr9"
start = 90_000_000
end = 92_000_000
plot_region = (chromsome, start, end)
ax_limit_extents = (start, end, end, start)
# Smoothing & Interpolation
ren_wt_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_wt_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_wt_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_wt_rep12_mcool_r10k_adcg_interp = interp_nan(ren_wt_rep12_mcool_r10k_adcg)

ren_iaa_rep12_mcool_r10k_adcg = adaptive_coarsegrain(ren_iaa_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                ren_iaa_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
ren_iaa_rep12_mcool_r10k_adcg_interp = interp_nan(ren_iaa_rep12_mcool_r10k_adcg)

wn_bpk25_rep12_mcool_r10k_adcg = adaptive_coarsegrain(wn_bpk25_rep12_mcool_r10k.matrix(balance=True).fetch(plot_region),
                                wn_bpk25_rep12_mcool_r10k.matrix(balance=False).fetch(plot_region), cutoff=3, max_levels=9)
wn_bpk25_rep12_mcool_r10k_adcg_interp = interp_nan(wn_bpk25_rep12_mcool_r10k_adcg)

# interpolation=['antialiased', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos', 'blackman']
figure, axes = plt.subplots(figsize=(12, 5), nrows=1, ncols=3, sharex=True, sharey=True)
figure.subplots_adjust(left=0.09, right=0.94, bottom=-0.3, top=1.35, wspace=0.08)
figure.suptitle(f'Zic1_flank_region ({chromsome}:{start:,}-{end:,})', y=0.96)
# ax1
ax1 = axes[0]
im1 = ax1.matshow(ren_wt_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax1.set_title('Ren_WT_r10k', y=1.01)
ax1.set_ylabel('position(Mb)')
# ax2
ax2 = axes[1]
im2 = ax2.matshow(ren_iaa_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax2.set_title('Ren_IAA_r10k', y=1.01)
# ax3
ax3 = axes[2]
im3 = ax3.matshow(wn_bpk25_rep12_mcool_r10k_adcg_interp*100000, vmin=0, vmax=700, cmap='fall', extent=ax_limit_extents)
ax3.set_title('WN_BPK25_r10k', y=1.01)

for ax in axes:
    format_ticks(ax)
    ax.set_xlabel('position(Mb)')
plt.colorbar(im3, ax=axes, fraction=0.014, label='(balance=True)', pad=0.02, aspect=22)
plt.savefig("view_Zic1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.pdf")
plt.savefig("view_Zic1_flank_use_Ren_WT_IAA_WN_BPK25.rep12merged.r10k.fall.heatmap.png")
plt.show()

# %%
import os
print(os.getcwd())
os.chdir("/data1/sunwenju/projects_on_940xa/2024041703_mESC_HiC_use_pairtools_cooler_pipeline/")
print(os.getcwd())

# %%
# %%bash
# mkdir comparable_heatmap_use_Ren_WT_IAA_WN_BPK25_r10k
# mv *Ren_WT_IAA_WN_BPK25*.rep12merged.r10k.fall.heatmap.png ./comparable_heatmap_use_Ren_WT_IAA_WN_BPK25_r10k/
# mv *Ren_WT_IAA_WN_BPK25*.rep12merged.r10k.fall.heatmap.pdf ./comparable_heatmap_use_Ren_WT_IAA_WN_BPK25_r10k/

# %%
! find . -name *Ren_WT_IAA_WN_BPK25*.rep12merged.r10k.fall.heatmap.png

# %%
import os
import glob
import platform

from PIL import Image
from pptx import Presentation
from pptx.util import Pt, Cm
from pptx.dml.color import RGBColor

os_name = platform.system()
print(os_name)
# 指定目录路径
directory = './comparable_heatmap_use_Ren_WT_IAA_WN_BPK25_r10k'
# 构建文件路径的通配符
file_pattern = os.path.join(directory, '*.rep12merged.r10k.fall.heatmap.png')
# 使用 glob 模块获取匹配的文件路径列表
png_files = sorted(glob.glob(file_pattern))
print(len(png_files))
# 打印文件路径列表
for file in png_files:
    # print(file)
    if os_name == 'Windows':
        print(file.split('\\')[2])
    else:
        print(file.split('/')[2])

# %% [markdown]
# # add rep12 merged r10k plot to summary ppt

# %%
import os
import glob
import platform

from PIL import Image
from pptx import Presentation
from pptx.util import Pt, Cm
from pptx.dml.color import RGBColor

os_name = platform.system()
# 指定目录路径
directory = './comparable_heatmap_use_Ren_WT_IAA_WN_BPK25_r10k'
# 构建文件路径的通配符
file_pattern = os.path.join(directory, '*.rep12merged.r10k.fall.heatmap.png')
# 使用 glob 模块获取匹配的文件路径列表
png_files = sorted(glob.glob(file_pattern))
# print(len(png_files))

# 打开 r20k 的 PPT 并插入图片
my_ppt = Presentation("4_Ren_WT_IAA_WN_BPK25.rep12merged.fall.heatmap.summary.pptx")
# 设置幻灯片尺寸为 16:9 (25.4cm *14.28cm)
my_ppt.slide_width = 9144000
my_ppt.slide_height = 5143500

page_count = len(png_files)
# print(page_count)
# jpg 图像文件处理序号
pi = 1
for i in range(1, page_count+1):
    # print(pi)
    # slide = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
    slide = my_ppt.slides[pi-1]
    # top
    if pi <= len(png_files):
        # 插入文本框
        # text_box = slide.shapes.add_textbox(left, top, width, height)
        text_box = slide.shapes.add_textbox(Cm(8.80), Cm(0+7.15), Cm(15.9), Cm(0.5))
        # 设置文本框背景颜色为黄色
        text_box.fill.solid()
        text_box.fill.fore_color.rgb = RGBColor(255, 230, 153)
        # 在文本框中添加内容并设置格式
        text_frame = text_box.text_frame
        if os_name == 'Linux':
            text_frame.text = png_files[pi-1].split('/')[2]
        elif os_name == 'Windows':
            text_frame.text = png_files[pi-1].split('\\')[2]
        # 设置字体大小和加粗
        text_font = text_frame.paragraphs[0].font
        text_font.name = '微软雅黑'
        text_font.size = Pt(6)
        text_font.bold = True
        # PPT 页面指定区域插入图片
        # pic = slide.shapes.add_picture(png_files[pi-1], left, top, width, height)
        pic = slide.shapes.add_picture(png_files[pi-1], Cm(8.80), Cm(0.50+7.15), Cm(15.9), Cm(6.6))
    # 页面索引 +1 
    pi += 1

# 保存 PPT
my_ppt.save('4_Ren_WT_IAA_WN_BPK25.rep12merged.fall.heatmap.summary.pptx')
