# %%
# ref: https://coolpuppy.readthedocs.io/en/latest/Examples/Walkthrough_API.html

# %%
import os
print(os.getcwd())
os.chdir("/data1/sunwenju/projects_on_940xa/2024041703_mESC_HiC_use_pairtools_cooler_pipeline")
print(os.getcwd())

# %%
! find . -name *rep12.merged.1k.zoomify.mcool

# %%
! find . -name *WT*rep1.*1k.zoomify.mcool

# %%
! find . -name *WT*rep2.*1k.zoomify.mcool

# %% [markdown]
# # 读取需要用到的文件

# %% [markdown]
# ## 读取 mcool 文件

# %%
import cooler
resolution = 10_000
# mcool 文件
nora_wt_mcool_file = "./Nora_WT/Nora_mESC_WT_HiC.rep12.merged.1k.zoomify.mcool"
nora_iaa_mcool_file = "./Nora_IAA/Nora_mESC_IAA_HiC.rep12.merged.1k.zoomify.mcool"
ren_wt_mcool_file = "./Ren_WT/Ren_mESC_WT_HiC.rep12.merged.1k.zoomify.mcool"
ren_iaa_mcool_file = "./Ren_IAA/Ren_mESC_IAA_HiC.rep12.merged.1k.zoomify.mcool"
wn_bpk25_mcool_file = "./WN_BPK25/WN_mESC_BPK25_HiC.rep12.merged.1k.zoomify.mcool"
# 生成 r10k cool 互作矩阵对象
nora_wt_r10k_clr = cooler.Cooler(f'{nora_wt_mcool_file}::/resolutions/{resolution}')
nora_iaa_r10k_clr = cooler.Cooler(f'{nora_iaa_mcool_file}::/resolutions/{resolution}')
ren_wt_r10k_clr = cooler.Cooler(f'{ren_wt_mcool_file}::/resolutions/{resolution}')
ren_iaa_r10k_clr = cooler.Cooler(f'{ren_iaa_mcool_file}::/resolutions/{resolution}')
wn_bpk25_r10k_clr = cooler.Cooler(f'{wn_bpk25_mcool_file}::/resolutions/{resolution}')

# %%
# Nora/Ren WT rep1/2 mcool 后续用于 divide pileup 表示 WT 两次重复之间没啥差异，用 IAA 或 BPK25 处理后有明显差异
nora_wt_rep1_mcool_file = "./Nora_WT/Nora_mESC_WT_HiC_rep1.nodups.pairs.1k.zoomify.mcool"
nora_wt_rep2_mcool_file = "./Nora_WT/Nora_mESC_WT_HiC_rep2.nodups.pairs.1k.zoomify.mcool"
ren_wt_rep1_mcool_file = "./Ren_WT/Ren_mESC_WT_HiC_rep1.nodups.pairs.1k.zoomify.mcool"
ren_wt_rep2_mcool_file = "./Ren_WT/Ren_mESC_WT_HiC_rep2.nodups.pairs.1k.zoomify.mcool"
# 生成 r10k cool 互作矩阵对象
nora_wt_rep1_r10k_clr = cooler.Cooler(f'{nora_wt_rep1_mcool_file}::/resolutions/{resolution}')
nora_wt_rep2_r10k_clr = cooler.Cooler(f'{nora_wt_rep2_mcool_file}::/resolutions/{resolution}')
ren_wt_rep1_r10k_clr = cooler.Cooler(f'{ren_wt_rep1_mcool_file}::/resolutions/{resolution}')
ren_wt_rep2_r10k_clr = cooler.Cooler(f'{ren_wt_rep2_mcool_file}::/resolutions/{resolution}')

# %% [markdown]
# ## 读取 chrom view 文件

# %%
import pandas as pd
mm10_chr_view_df = pd.read_csv("./mm10.chrom.view.tsv", sep="\t", header=0)
print(mm10_chr_view_df.shape)
mm10_chr_view_df.head()

# %% [markdown]
# # 计算生成 expected_cis_df

# %%
from cooltools import expected_cis
# Calculate expected interactions for chromosome arms
nora_wt_r10k_expected_cis_df = expected_cis(clr=nora_wt_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
nora_iaa_r10k_expected_cis_df = expected_cis(clr=nora_iaa_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
ren_wt_r10k_expected_cis_df = expected_cis(clr=ren_wt_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
ren_iaa_r10k_expected_cis_df = expected_cis(clr=ren_iaa_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
wn_bpk25_r10k_expected_cis_df = expected_cis(clr=wn_bpk25_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)

# %%
# Nora/Ren WT rep1/2 expected_cis_df
nora_wt_rep1_r10k_expected_cis_df = expected_cis(clr=nora_wt_rep1_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
nora_wt_rep2_r10k_expected_cis_df = expected_cis(clr=nora_wt_rep2_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
ren_wt_rep1_r10k_expected_cis_df = expected_cis(clr=ren_wt_rep1_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)
ren_wt_rep2_r10k_expected_cis_df = expected_cis(clr=ren_wt_rep2_r10k_clr, view_df=mm10_chr_view_df, ignore_diags=1, nproc=128)

# %% [markdown]
# # 读取 Ren_WT r10k TADs 结果文件

# %%
! find . -name *.rep12.merged.mcool_r10k.w15r.TADs.bed

# %%
ren_wt_r10k_tads_file = "./Ren_WT/Ren_mESC_WT_HiC.rep12.merged.mcool_r10k.w15r.TADs.bed"
ren_wt_r10k_tads_df = pd.read_csv(ren_wt_r10k_tads_file, sep="\t", header=None)
ren_wt_r10k_tads_df.columns = ["chrom", "start", "end"]
ren_wt_r10k_tads_df["tad_len"] = ren_wt_r10k_tads_df.end - ren_wt_r10k_tads_df.start
print(ren_wt_r10k_tads_df.shape)
ren_wt_r10k_tads_df.head()

# %%
pd.set_option('display.float_format', lambda x: '%d' % x)
ren_wt_r10k_tads_df.tad_len.describe()

# %% [markdown]
# ## 根据 tad length 四分类

# %%
ren_wt_r10k_tads_df["len_quartile"] = pd.qcut(ren_wt_r10k_tads_df['tad_len'], 4, labels=False) + 1
print(ren_wt_r10k_tads_df.shape)
ren_wt_r10k_tads_df.head()

# %%
ren_wt_r10k_tads_df.len_quartile.value_counts().sort_index()

# %%
ren_wt_r10k_tads_df.groupby("len_quartile").tad_len.mean()

# %% [markdown]
# # Ren_WT r10k TADs 不分组 pileup

# %% [markdown]
# ## Nora_WT

# %%
from coolpuppy import coolpup
nora_wt_r10k_clr_tads_pup = coolpup.pileup(clr=nora_wt_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
nora_wt_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_wt_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT.png")

# %% [markdown]
# ## Nora_WT_rep1

# %%
from coolpuppy import coolpup
nora_wt_rep1_r10k_clr_tads_pup = coolpup.pileup(clr=nora_wt_rep1_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_rep1_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
nora_wt_rep1_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_wt_rep1_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep1.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep1.png")

# %% [markdown]
# ## Nora_WT_rep2

# %%
from coolpuppy import coolpup
nora_wt_rep2_r10k_clr_tads_pup = coolpup.pileup(clr=nora_wt_rep2_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_rep2_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
nora_wt_rep2_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_wt_rep2_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2.png")

# %% [markdown]
# ## Nora_IAA

# %%
from coolpuppy import coolpup
nora_iaa_r10k_clr_tads_pup = coolpup.pileup(clr=nora_iaa_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_iaa_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
nora_iaa_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_iaa_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA.png")

# %% [markdown]
# ## Ren_WT

# %%
from coolpuppy import coolpup
ren_wt_r10k_clr_tads_pup = coolpup.pileup(clr=ren_wt_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
ren_wt_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=ren_wt_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT.png")

# %% [markdown]
# ## Ren_WT_rep1

# %%
from coolpuppy import coolpup
ren_wt_rep1_r10k_clr_tads_pup = coolpup.pileup(clr=ren_wt_rep1_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_rep1_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
ren_wt_rep1_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=ren_wt_rep1_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep1.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep1.png")

# %% [markdown]
# ## Ren_WT_rep2

# %%
from coolpuppy import coolpup
ren_wt_rep2_r10k_clr_tads_pup = coolpup.pileup(clr=ren_wt_rep2_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_rep2_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
ren_wt_rep2_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=ren_wt_rep2_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2.png")

# %% [markdown]
# ## Ren_IAA

# %%
from coolpuppy import coolpup
ren_iaa_r10k_clr_tads_pup = coolpup.pileup(clr=ren_iaa_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_iaa_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
ren_iaa_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=ren_iaa_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA.png")

# %% [markdown]
# ## WN_BPK25

# %%
from coolpuppy import coolpup
wn_bpk25_r10k_clr_tads_pup = coolpup.pileup(clr=wn_bpk25_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=wn_bpk25_r10k_expected_cis_df,
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
wn_bpk25_r10k_clr_tads_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=wn_bpk25_r10k_clr_tads_pup,
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25.png")

# %% [markdown]
# ## Nora_WT_IAA_WN_BPK25_merge_in_one

# %%
# nora_wt_r10k_clr_tads_pup
# nora_iaa_r10k_clr_tads_pup
# wn_bpk25_r10k_clr_tads_pup
nora_wn_tads_pup_merged_df = pd.concat([nora_wt_r10k_clr_tads_pup, nora_iaa_r10k_clr_tads_pup, wn_bpk25_r10k_clr_tads_pup], ignore_index=True)
nora_wn_tads_pup_merged_df

# %%
nora_wn_tads_pup_merged_df["group"] = ["Nora_WT", "Nora_IAA", "WN_BPK25"]
nora_wn_tads_pup_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_wn_tads_pup_merged_df,
                cols="group",
                col_order=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                colnames=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN.png")

# %% [markdown]
# ## Ren_WT_IAA_WN_BPK25_merge_in_one

# %%
# ren_wt_r10k_clr_tads_pup
# ren_iaa_r10k_clr_tads_pup
# wn_bpk25_r10k_clr_tads_pup
ren_wn_tads_pup_merged_df = pd.concat([ren_wt_r10k_clr_tads_pup, ren_iaa_r10k_clr_tads_pup, wn_bpk25_r10k_clr_tads_pup], ignore_index=True)
ren_wn_tads_pup_merged_df

# %%
ren_wn_tads_pup_merged_df["group"] = ["Ren_WT", "Ren_IAA", "WN_BPK25"]
ren_wn_tads_pup_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=ren_wn_tads_pup_merged_df,
                cols="group",
                col_order=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                colnames=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WN.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WN.png")

# %% [markdown]
# ## all experiment merge in one

# %%
nora_wn_ren_tads_pup_merged_df = pd.concat([nora_wt_r10k_clr_tads_pup, nora_iaa_r10k_clr_tads_pup, wn_bpk25_r10k_clr_tads_pup, ren_iaa_r10k_clr_tads_pup, ren_wt_r10k_clr_tads_pup], ignore_index=True)
nora_wn_ren_tads_pup_merged_df

# %%
nora_wn_ren_tads_pup_merged_df["group"] = ["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"]
nora_wn_ren_tads_pup_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=nora_wn_ren_tads_pup_merged_df,
                cols="group",
                col_order=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                colnames=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN_Ren.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN_Ren.png")

# %% [markdown]
# ## Nora_WT_rep2_vs_rep1

# %%
# nora_wt_rep1_r10k_clr_tads_pup
# nora_wt_rep2_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_nora_wt_rep2_vs_rep1 = divide_pups(nora_wt_rep2_r10k_clr_tads_pup, nora_wt_rep1_r10k_clr_tads_pup)
tads_pup_nora_wt_rep2_vs_rep1

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_nora_wt_rep2_vs_rep1,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})\n Nora_WT_rep2_vs_rep1')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2_vs_rep1.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2_vs_rep1.png")

# %% [markdown]
# ## Ren_WT_rep2_vs_rep1

# %%
# ren_wt_rep1_r10k_clr_tads_pup
# ren_wt_rep2_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_ren_wt_rep2_vs_rep1 = divide_pups(ren_wt_rep2_r10k_clr_tads_pup, ren_wt_rep1_r10k_clr_tads_pup)
tads_pup_ren_wt_rep2_vs_rep1

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_ren_wt_rep2_vs_rep1,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})\n Ren_WT_rep2_vs_rep1')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2_vs_rep1.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2_vs_rep1.png")

# %% [markdown]
# ## Nora_IAA_vs_WT

# %%
# nora_iaa_r10k_clr_tads_pup
# nora_wt_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_nora_iaa_vs_wt = divide_pups(nora_iaa_r10k_clr_tads_pup, nora_wt_r10k_clr_tads_pup)
tads_pup_nora_iaa_vs_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_nora_iaa_vs_wt,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})\n Nora_IAA_vs_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA_vs_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA_vs_WT.png")

# %% [markdown]
# ## Ren_IAA_vs_WT

# %%
# ren_iaa_r10k_clr_tads_pup
# ren_wt_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_ren_iaa_vs_wt = divide_pups(ren_iaa_r10k_clr_tads_pup, ren_wt_r10k_clr_tads_pup)
tads_pup_ren_iaa_vs_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_ren_iaa_vs_wt,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})\n Ren_IAA_vs_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA_vs_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA_vs_WT.png")

# %% [markdown]
# ## WN_BPK25_vs_Nora_WT

# %%
# wn_bpk25_r10k_clr_tads_pup
# nora_wt_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_wn_bpk25_vs_nora_wt = divide_pups(wn_bpk25_r10k_clr_tads_pup, nora_wt_r10k_clr_tads_pup)
tads_pup_wn_bpk25_vs_nora_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_wn_bpk25_vs_nora_wt,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]}) \n WN_BPK25_vs_Nora_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Nora_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Nora_WT.png")

# %% [markdown]
# ## WN_BPK25_vs_Ren_WT

# %%
# wn_bpk25_r10k_clr_tads_pup
# ren_wt_r10k_clr_tads_pup
from coolpuppy.lib.puputils import divide_pups
tads_pup_wn_bpk25_vs_ren_wt = divide_pups(wn_bpk25_r10k_clr_tads_pup, ren_wt_r10k_clr_tads_pup)
tads_pup_wn_bpk25_vs_ren_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_wn_bpk25_vs_ren_wt,
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]}) \n WN_BPK25_vs_Ren_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Ren_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Ren_WT.png")

# %% [markdown]
# ## merge 4 divide pileup in one

# %%
tads_pup_divide_merged_df = pd.concat([tads_pup_nora_iaa_vs_wt, tads_pup_ren_iaa_vs_wt, tads_pup_wn_bpk25_vs_nora_wt, tads_pup_wn_bpk25_vs_ren_wt], ignore_index=True)
tads_pup_divide_merged_df

# %%
tads_pup_divide_merged_df.insert(0, "comparation", ["IAA_vs_WT", "IAA_vs_WT", "BPK25_vs_WT", "BPK25_vs_WT"] )
tads_pup_divide_merged_df.insert(1, "WT_source", ["Nora", "Ren", "Nora", "Ren"] )
tads_pup_divide_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                rows="comparation",
                row_order=["IAA_vs_WT", "BPK25_vs_WT"],
                rownames=["IAA_vs_WT", "BPK25_vs_WT"],
                cols='WT_source',
                col_order=["Nora", "Ren"],
                colnames=["use_Nora_WT", "use_Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_4comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_4comparation.exp_col.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                cols="comparation",
                col_order=["IAA_vs_WT", "BPK25_vs_WT"],
                colnames=["IAA_vs_WT", "BPK25_vs_WT"],
                rows='WT_source',
                row_order=["Nora", "Ren"],
                rownames=["use_Nora_WT", "use_Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_4comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_4comparation.exp_row.png")

# %% [markdown]
# ## merge 6 divide pileup in one

# %%
tads_pup_divide_merged_df = pd.concat([tads_pup_nora_wt_rep2_vs_rep1, tads_pup_ren_wt_rep2_vs_rep1, tads_pup_nora_iaa_vs_wt, tads_pup_ren_iaa_vs_wt, tads_pup_wn_bpk25_vs_nora_wt, tads_pup_wn_bpk25_vs_ren_wt], ignore_index=True)
tads_pup_divide_merged_df

# %%
tads_pup_divide_merged_df.insert(0, "comp_group", ["WT_rep2vs1", "WT_rep2vs1", "IAA_vs_WT", "IAA_vs_WT", "BPK25_vs_WT", "BPK25_vs_WT"] )
tads_pup_divide_merged_df.insert(1, "WT_source", ["Nora", "Ren", "Nora", "Ren", "Nora", "Ren"] )
tads_pup_divide_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                rows="comp_group",
                row_order=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                rownames=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                cols='WT_source',
                col_order=["Nora", "Ren"],
                colnames=["use_Nora_WT", "use_Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_6comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_6comparation.exp_col.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                cols="comp_group",
                col_order=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                colnames=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                rows='WT_source',
                row_order=["Nora", "Ren"],
                rownames=["use_Nora_WT", "use_Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_6comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_6comparation.exp_row.png")

# %% [markdown]
# ## merge plot for Nora WN 3 comparation

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                cols="comp_group",
                col_order=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                colnames=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                rows='WT_source',
                row_order=["Nora"],
                rownames=["use_Nora_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Nora_WN_3comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Nora_WN_3comparation.exp_row.png")

# %% [markdown]
# ## merge plot for Ren WN 3 comparation

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
plotpup.plot(pupsdf=tads_pup_divide_merged_df,
                cols="comp_group",
                col_order=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                colnames=["WT_rep2vs1", "IAA_vs_WT", "BPK25_vs_WT"],
                rows='WT_source',
                row_order=["Ren"],
                rownames=["use_Ren_WT"],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.suptitle(f'Ren_WT_r10k_TADs ({ren_wt_r10k_tads_df.shape[0]})')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Ren_WN_3comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Ren_WN_3comparation.exp_row.png")

# %% [markdown]
# # Ren_WT r10k TADs 根据 tad_len 分四组 pileup

# %% [markdown]
# ## Nora_WT

# %%
from coolpuppy import coolpup
nora_wt_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=nora_wt_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=128)
nora_wt_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts().sort_index()
plotpup.plot(pupsdf=nora_wt_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT.png")

# %% [markdown]
# ## Nora_WT_rep1

# %%
from coolpuppy import coolpup
nora_wt_rep1_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=nora_wt_rep1_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_rep1_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
nora_wt_rep1_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=nora_wt_rep1_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep1.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep1.png")

# %% [markdown]
# ## Nora_WT_rep2

# %%
from coolpuppy import coolpup
nora_wt_rep2_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=nora_wt_rep2_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_wt_rep2_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
nora_wt_rep2_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=nora_wt_rep2_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2.png")

# %% [markdown]
# ## Nora_IAA

# %%
from coolpuppy import coolpup
nora_iaa_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=nora_iaa_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=nora_iaa_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
nora_iaa_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=nora_iaa_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA.png")

# %% [markdown]
# ## Ren_WT

# %%
from coolpuppy import coolpup
ren_wt_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=ren_wt_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
ren_wt_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=ren_wt_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT.png")

# %% [markdown]
# ## Ren_WT_rep1

# %%
from coolpuppy import coolpup
ren_wt_rep1_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=ren_wt_rep1_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_rep1_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
ren_wt_rep1_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=ren_wt_rep1_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep1.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep1.png")

# %% [markdown]
# ## Ren_WT_rep2

# %%
from coolpuppy import coolpup
ren_wt_rep2_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=ren_wt_rep2_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_wt_rep2_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
ren_wt_rep2_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=ren_wt_rep2_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2.png")

# %% [markdown]
# ## Ren_IAA

# %%
from coolpuppy import coolpup
ren_iaa_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=ren_iaa_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=ren_iaa_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
ren_iaa_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=ren_iaa_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA.png")

# %% [markdown]
# ## WN_BPK25

# %%
from coolpuppy import coolpup
wn_bpk25_r10k_clr_tads_lenQ4c_pup = coolpup.pileup(clr=wn_bpk25_r10k_clr, 
                                            features=ren_wt_r10k_tads_df,
                                            features_format='bed', 
                                            view_df=mm10_chr_view_df,
                                            expected_df=wn_bpk25_r10k_expected_cis_df,
                                            groupby=["len_quartile1"],
                                            min_diag=0,
                                            local=True,
                                            rescale=True,
                                            rescale_flank=1,
                                            rescale_size=99,
                                            nproc=32)
wn_bpk25_r10k_clr_tads_lenQ4c_pup

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=wn_bpk25_r10k_clr_tads_lenQ4c_pup,
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25.png")

# %% [markdown]
# ## Nora_WT_IAA_WN_BPK25_merge_in_one

# %%
boundary_lenQ4c_pup_nora_wn_merged_df = pd.concat([nora_wt_r10k_clr_tads_lenQ4c_pup, nora_iaa_r10k_clr_tads_lenQ4c_pup, wn_bpk25_r10k_clr_tads_lenQ4c_pup], ignore_index=True)
boundary_lenQ4c_pup_nora_wn_merged_df

# %%
boundary_lenQ4c_pup_nora_wn_merged_df["group"] = ["Nora_WT"]*5 + ["Nora_IAA"]*5 + ["WN_BPK25"]*5
boundary_lenQ4c_pup_nora_wn_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_nora_wn_merged_df,
                rows="group",
                row_order=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                rownames=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_row.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_row.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_nora_wn_merged_df,
                cols="group",
                col_order=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                colnames=["Nora_WT", "Nora_IAA", "WN_BPK25"],
                rows="len_quartile1",
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_col.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_col.png")

# %% [markdown]
# ## Ren_WT_IAA_WN_BPK25_merge_in_one

# %%
boundary_lenQ4c_pup_ren_wn_merged_df = pd.concat([ren_wt_r10k_clr_tads_lenQ4c_pup, ren_iaa_r10k_clr_tads_lenQ4c_pup, wn_bpk25_r10k_clr_tads_lenQ4c_pup], ignore_index=True)
boundary_lenQ4c_pup_ren_wn_merged_df

# %%
boundary_lenQ4c_pup_ren_wn_merged_df["group"] = ["Ren_WT"]*5 + ["Ren_IAA"]*5 + ["WN_BPK25"]*5
boundary_lenQ4c_pup_ren_wn_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_ren_wn_merged_df,
                rows="group",
                row_order=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                rownames=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_row.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_row.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_ren_wn_merged_df,
                cols="group",
                col_order=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                colnames=["Ren_WT", "Ren_IAA", "WN_BPK25"],
                rows="len_quartile1",
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_col.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_col.png")

# %% [markdown]
# ## all experiment merge in one

# %%
boundary_lenQ4c_pup_nora_wn_ren_merged_df = pd.concat([nora_wt_r10k_clr_tads_lenQ4c_pup, nora_iaa_r10k_clr_tads_lenQ4c_pup, wn_bpk25_r10k_clr_tads_lenQ4c_pup, ren_iaa_r10k_clr_tads_lenQ4c_pup, ren_wt_r10k_clr_tads_lenQ4c_pup], ignore_index=True)
boundary_lenQ4c_pup_nora_wn_ren_merged_df

# %%
boundary_lenQ4c_pup_nora_wn_ren_merged_df["group"] = ["Nora_WT"]*5 + ["Nora_IAA"]*5 + ["WN_BPK25"]*5 + ["Ren_IAA"]*5 + ["Ren_WT"]*5
boundary_lenQ4c_pup_nora_wn_ren_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_nora_wn_ren_merged_df,
                rows="group",
                row_order=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                rownames=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                cols="len_quartile1",
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_row.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_row.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=boundary_lenQ4c_pup_nora_wn_ren_merged_df,
                cols="group",
                col_order=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                colnames=["Nora_WT", "Nora_IAA", "WN_BPK25", "Ren_IAA", "Ren_WT"],
                rows="len_quartile1",
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_col.pdf")
plt.savefig("coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_col.png")

# %% [markdown]
# ## Nora_WT_rep2_vs_rep1

# %%
# nora_wt_rep1_r10k_clr_tads_lenQ4c_pup
# nora_wt_rep2_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    rep1_pup = nora_wt_rep1_r10k_clr_tads_lenQ4c_pup[nora_wt_rep1_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    rep2_pup = nora_wt_rep2_r10k_clr_tads_lenQ4c_pup[nora_wt_rep2_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    rep2_vs_rep1 = divide_pups(rep2_pup, rep1_pup)
    all_lenQ4c_group_divide_pup.append(rep2_vs_rep1)
TADs_lenQ4c_pup_nora_wt_rep2_vs_rep1 = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_nora_wt_rep2_vs_rep1

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_nora_wt_rep2_vs_rep1,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Nora_WT_rep2_vs_rep1')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2_vs_rep1.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2_vs_rep1.png")

# %% [markdown]
# ## Ren_WT_rep2_vs_rep1

# %%
# ren_wt_rep1_r10k_clr_tads_lenQ4c_pup
# ren_wt_rep2_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    rep1_pup = ren_wt_rep1_r10k_clr_tads_lenQ4c_pup[ren_wt_rep1_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    rep2_pup = ren_wt_rep2_r10k_clr_tads_lenQ4c_pup[ren_wt_rep2_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    rep2_vs_rep1 = divide_pups(rep2_pup, rep1_pup)
    all_lenQ4c_group_divide_pup.append(rep2_vs_rep1)
TADs_lenQ4c_pup_ren_wt_rep2_vs_rep1 = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_ren_wt_rep2_vs_rep1

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_ren_wt_rep2_vs_rep1,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_WT_rep2_vs_rep1')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2_vs_rep1.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2_vs_rep1.png")

# %% [markdown]
# ## Nora_IAA_vs_WT

# %%
# nora_wt_r10k_clr_tads_lenQ4c_pup
# nora_iaa_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    nora_iaa_pup = nora_iaa_r10k_clr_tads_lenQ4c_pup[nora_iaa_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    nora_wt_pup = nora_wt_r10k_clr_tads_lenQ4c_pup[nora_wt_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    nora_iaa_vs_wt = divide_pups(nora_iaa_pup, nora_wt_pup)
    all_lenQ4c_group_divide_pup.append(nora_iaa_vs_wt)
TADs_lenQ4c_pup_nora_iaa_vs_wt = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_nora_iaa_vs_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_nora_iaa_vs_wt,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Nora_IAA_vs_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA_vs_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA_vs_WT.png")

# %% [markdown]
# ## Ren_IAA_vs_WT

# %%
# ren_wt_r10k_clr_tads_lenQ4c_pup
# ren_iaa_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    ren_iaa_pup = ren_iaa_r10k_clr_tads_lenQ4c_pup[ren_iaa_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    ren_wt_pup = ren_wt_r10k_clr_tads_lenQ4c_pup[ren_wt_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    ren_iaa_vs_wt = divide_pups(ren_iaa_pup, ren_wt_pup)
    all_lenQ4c_group_divide_pup.append(ren_iaa_vs_wt)
TADs_lenQ4c_pup_ren_iaa_vs_wt = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_ren_iaa_vs_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_ren_iaa_vs_wt,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'Ren_IAA_vs_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA_vs_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA_vs_WT.png")

# %% [markdown]
# ## WN_BPK25_vs_Nora_WT

# %%
# nora_wt_r10k_clr_tads_lenQ4c_pup
# wn_bpk25_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    wn_bpk25_pup = wn_bpk25_r10k_clr_tads_lenQ4c_pup[wn_bpk25_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    nora_wt_pup = nora_wt_r10k_clr_tads_lenQ4c_pup[nora_wt_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    wn_bpk25_vs_nora_wt = divide_pups(wn_bpk25_pup, nora_wt_pup)
    all_lenQ4c_group_divide_pup.append(wn_bpk25_vs_nora_wt)
TADs_lenQ4c_pup_wn_bpk25_vs_nora_wt = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_wn_bpk25_vs_nora_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_wn_bpk25_vs_nora_wt,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'WN_BPK25_vs_Nora_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Nora_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Nora_WT.png")

# %% [markdown]
# ## WN_BPK25_vs_Ren_WT

# %%
# ren_wt_r10k_clr_tads_lenQ4c_pup
# wn_bpk25_r10k_clr_tads_lenQ4c_pup
from coolpuppy.lib.puputils import divide_pups
all_lenQ4c_group_divide_pup = []
for lenQ4c_group in ["all", 1, 2, 3, 4]:
    wn_bpk25_pup = wn_bpk25_r10k_clr_tads_lenQ4c_pup[wn_bpk25_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    ren_wt_pup = ren_wt_r10k_clr_tads_lenQ4c_pup[ren_wt_r10k_clr_tads_lenQ4c_pup.len_quartile1==lenQ4c_group]
    wn_bpk25_vs_ren_wt = divide_pups(wn_bpk25_pup, ren_wt_pup)
    all_lenQ4c_group_divide_pup.append(wn_bpk25_vs_ren_wt)
TADs_lenQ4c_pup_wn_bpk25_vs_ren_wt = pd.concat(all_lenQ4c_group_divide_pup, ignore_index=True)
TADs_lenQ4c_pup_wn_bpk25_vs_ren_wt

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_wn_bpk25_vs_ren_wt,
            cols='len_quartile1',
            col_order=["all", 1, 2, 3, 4],
            colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
            score=True,
            sym=True,
            cmap='coolwarm',
            scale='log',
            height=5,
            font_scale=1.2,
            plot_ticks=True)
plt.suptitle(f'WN_BPK25_vs_Ren_WT')
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Ren_WT.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Ren_WT.png")

# %% [markdown]
# ## merge 4 divide pileup in one

# %%
TADs_lenQ4c_pup_divide_merged_df = pd.concat([TADs_lenQ4c_pup_nora_iaa_vs_wt, TADs_lenQ4c_pup_ren_iaa_vs_wt, TADs_lenQ4c_pup_wn_bpk25_vs_nora_wt, TADs_lenQ4c_pup_wn_bpk25_vs_ren_wt], ignore_index=True)
TADs_lenQ4c_pup_divide_merged_df

# %%
TADs_lenQ4c_pup_divide_merged_df.insert(0, "divide_group", ["Nora_IAA_vs_WT"]*5+["Ren_IAA_vs_WT"]*5+["WN_BPK25_vs_Nora_WT"]*5+["WN_BPK25_vs_Ren_WT"]*5)
TADs_lenQ4c_pup_divide_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                rows="divide_group",
                row_order=["Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                rownames=["Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                cols='len_quartile1',
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_4comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_4comparation.exp_row.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                cols="divide_group",
                col_order=["Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                colnames=["Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                rows='len_quartile1',
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_4comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_4comparation.exp_col.png")

# %% [markdown]
# ## merge 6 divide pileup in one

# %%
TADs_lenQ4c_pup_divide_merged_df = pd.concat([TADs_lenQ4c_pup_nora_wt_rep2_vs_rep1, TADs_lenQ4c_pup_ren_wt_rep2_vs_rep1, TADs_lenQ4c_pup_nora_iaa_vs_wt, TADs_lenQ4c_pup_ren_iaa_vs_wt, TADs_lenQ4c_pup_wn_bpk25_vs_nora_wt, TADs_lenQ4c_pup_wn_bpk25_vs_ren_wt], ignore_index=True)
TADs_lenQ4c_pup_divide_merged_df

# %%
TADs_lenQ4c_pup_divide_merged_df.insert(0, "divide_group", ["Nora_WT_rep2vs1"]*5+["Ren_WT_rep2vs1"]*5+["Nora_IAA_vs_WT"]*5+["Ren_IAA_vs_WT"]*5+["WN_BPK25_vs_Nora_WT"]*5+["WN_BPK25_vs_Ren_WT"]*5)
TADs_lenQ4c_pup_divide_merged_df

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                rows="divide_group",
                row_order=["Nora_WT_rep2vs1", "Ren_WT_rep2vs1", "Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                rownames=["Nora_WT_rep2vs1", "Ren_WT_rep2vs1", "Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                cols='len_quartile1',
                col_order=["all", 1, 2, 3, 4],
                colnames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_6comparation.exp_row.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_6comparation.exp_row.png")

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                cols="divide_group",
                col_order=["Nora_WT_rep2vs1", "Ren_WT_rep2vs1", "Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                colnames=["Nora_WT_rep2vs1", "Ren_WT_rep2vs1", "Nora_IAA_vs_WT", "Ren_IAA_vs_WT", "WN_BPK25_vs_Nora_WT", "WN_BPK25_vs_Ren_WT"],
                rows='len_quartile1',
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_6comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_6comparation.exp_col.png")

# %% [markdown]
# ## merge plot for Nora WN 3 comparation

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                cols="divide_group",
                col_order=["Nora_WT_rep2vs1", "Nora_IAA_vs_WT", "WN_BPK25_vs_Nora_WT"],
                colnames=["Nora_WT_rep2vs1", "Nora_IAA_vs_WT", "WN_BPK25_vs_Nora_WT"],
                rows='len_quartile1',
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Nora_WN_3comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Nora_WN_3comparation.exp_col.png")

# %% [markdown]
# ## merge plot for Ren WN 3 comparation

# %%
import matplotlib.pyplot as plt
from coolpuppy import plotpup
Qcounts = ren_wt_r10k_tads_df.len_quartile.value_counts()
plotpup.plot(pupsdf=TADs_lenQ4c_pup_divide_merged_df,
                cols="divide_group",
                col_order=["Ren_WT_rep2vs1", "Ren_IAA_vs_WT", "WN_BPK25_vs_Ren_WT"],
                colnames=["Ren_WT_rep2vs1", "Ren_IAA_vs_WT", "WN_BPK25_vs_Ren_WT"],
                rows='len_quartile1',
                row_order=["all", 1, 2, 3, 4],
                rownames=[f'Ren_WT_r10k_TADs\n({ren_wt_r10k_tads_df.shape[0]})', f'len_Q1_TADs\n({Qcounts[1]})', f'len_Q2_TADs\n({Qcounts[2]})', f'len_Q3_TADs\n({Qcounts[3]})', f'len_Q4_TADs\n({Qcounts[4]})'],
                score=True,
                sym=True,
                cmap='coolwarm',
                scale='log',
                height=5,
                font_scale=1.2,
                plot_ticks=True)
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Ren_WN_3comparation.exp_col.pdf")
plt.savefig("coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Ren_WN_3comparation.exp_col.png")

# %% [markdown]
# # 制作结果汇总 PPT

# %%
! ls -1 coolpuppy_*for_Ren_WT_r10k_TADs*.pdf

# %%
! ls -1 coolpuppy_*for_Ren_WT_r10k_TADs*.png

# %% [markdown]
# ## add TADs_noClassified

# %%
from PIL import Image
from pptx import Presentation
from pptx.util import Pt, Cm
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN

ren_wt_r10k_TADs_noC_Nora_WT_rep1_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep1.png"
ren_wt_r10k_TADs_noC_Nora_WT_rep2_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2.png"
ren_wt_r10k_TADs_noC_Ren_WT_rep1_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep1.png"
ren_wt_r10k_TADs_noC_Ren_WT_rep2_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2.png"

ren_wt_r10k_TADs_noC_Nora_WT_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT.png"
ren_wt_r10k_TADs_noC_Nora_IAA_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA.png"
ren_wt_r10k_TADs_noC_Ren_WT_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT.png"
ren_wt_r10k_TADs_noC_Ren_IAA_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA.png"
ren_wt_r10k_TADs_noC_WN_BPK25_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25.png"

ren_wt_r10k_TADs_noC_Nora_WN_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN.png"
ren_wt_r10k_TADs_noC_Ren_WN_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WN.png"
ren_wt_r10k_TADs_noC_Nora_WN_Ren_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WN_Ren.png"

def add_text_anno(slide, anno_text, left, top, width, height):
    # 插入文本框
    text_box = slide.shapes.add_textbox(left, top, width, height)
    # 设置文本框背景颜色为黄色
    text_box.fill.solid()
    text_box.fill.fore_color.rgb = RGBColor(255, 230, 153)
    # 在文本框中添加内容并设置格式
    text_box.text_frame.text = anno_text
    text_box.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
    # 设置字体大小和加粗
    text_font = text_box.text_frame.paragraphs[0].font
    text_font.name = '微软雅黑'
    text_font.size = Pt(6)
    text_font.bold = True


# 创建 PPT 并插入图片
my_ppt = Presentation()
# 设置幻灯片尺寸为 16:9 (25.4cm *14.28cm)
my_ppt.slide_width = 9144000
my_ppt.slide_height = 5143500

# slide1
slide1 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
# pic = slide.shapes.add_picture(png_file, left, top, width, height)
slide1.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_WT_rep1_png, Cm(3.51), Cm(0.61), Cm(6.53), Cm(6.53))
slide1.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_WT_rep2_png, Cm(15.37), Cm(0.61), Cm(6.53), Cm(6.53))
slide1.shapes.add_picture(ren_wt_r10k_TADs_noC_Ren_WT_rep1_png, Cm(3.51), Cm(7.76), Cm(6.53), Cm(6.53))
slide1.shapes.add_picture(ren_wt_r10k_TADs_noC_Ren_WT_rep2_png, Cm(15.37), Cm(7.76), Cm(6.53), Cm(6.53))
# 插入文本注释
add_text_anno(slide1, "ren_wt_r10k_TADs_noC_Nora_WT_rep1_pileup_plot", Cm(3.21), Cm(0.05), Cm(7.14), Cm(0.5))
add_text_anno(slide1, "ren_wt_r10k_TADs_noC_Nora_WT_rep2_pileup_plot", Cm(15.07), Cm(0.05), Cm(7.14), Cm(0.5))
add_text_anno(slide1, "ren_wt_r10k_TADs_noC_Ren_WT_rep1_pileup_plot", Cm(3.21), Cm(7.19), Cm(7.14), Cm(0.5))
add_text_anno(slide1, "ren_wt_r10k_TADs_noC_Ren_WT_rep2_pileup_plot", Cm(15.07), Cm(7.19), Cm(7.14), Cm(0.5))

# slide2
slide2 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide2.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_WT_png, Cm(0.83), Cm(0.61), Cm(6.53), Cm(6.53))
slide2.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_IAA_png, Cm(9.38), Cm(0.61), Cm(6.53), Cm(6.53))
slide2.shapes.add_picture(ren_wt_r10k_TADs_noC_WN_BPK25_png, Cm(18.03), Cm(0.61), Cm(6.53), Cm(6.53))
slide2.shapes.add_picture(ren_wt_r10k_TADs_noC_Ren_WT_png, Cm(0.83), Cm(7.76), Cm(6.53), Cm(6.53))
slide2.shapes.add_picture(ren_wt_r10k_TADs_noC_Ren_IAA_png, Cm(9.38), Cm(7.76), Cm(6.53), Cm(6.53))
# 插入文本注释
add_text_anno(slide2, "ren_wt_r10k_TADs_noC_Nora_WT_pileup_plot", Cm(0.1), Cm(0.05), Cm(8), Cm(0.5))
add_text_anno(slide2, "ren_wt_r10k_TADs_noC_Nora_IAA_pileup_plot", Cm(8.65), Cm(0.05), Cm(8), Cm(0.5))
add_text_anno(slide2, "ren_wt_r10k_TADs_noC_WN_BPK25_pileup_plot", Cm(17.3), Cm(0.05), Cm(8), Cm(0.5))
add_text_anno(slide2, "ren_wt_r10k_TADs_noC_Ren_WT_pileup_plot", Cm(0.1), Cm(7.24), Cm(8), Cm(0.5))
add_text_anno(slide2, "ren_wt_r10k_TADs_noC_Ren_IAA_pileup_plot", Cm(8.65), Cm(7.24), Cm(8), Cm(0.5))

# slide3
slide3 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide3.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_WN_png, Cm(6.23), Cm(0.02), Cm(12.94), Cm(4.31))
slide3.shapes.add_picture(ren_wt_r10k_TADs_noC_Ren_WN_png, Cm(6.23), Cm(4.54),  Cm(12.94), Cm(4.31))
slide3.shapes.add_picture(ren_wt_r10k_TADs_noC_Nora_WN_Ren_png, Cm(0), Cm(9.04), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide3, "ren_wt_r10k_TADs_noC_Nora_WN_pileup_plot", Cm(0.28), Cm(1.92), Cm(7), Cm(0.5))
add_text_anno(slide3, "ren_wt_r10k_TADs_noC_Ren_WN_pileup_plot", Cm(0.28), Cm(6.44), Cm(7), Cm(0.5))
add_text_anno(slide3, "ren_wt_r10k_TADs_noC_Nora_WN_pileup_plot", Cm(0.28), Cm(8.86), Cm(7), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %%
ren_wt_r10k_TADs_noC_nora_rep2vs1 = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_WT_rep2_vs_rep1.png"
ren_wt_r10k_TADs_noC_nora_iaa_vs_wt = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Nora_IAA_vs_WT.png"
ren_wt_r10k_TADs_noC_wn_bpk25_vs_nora_wt = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Nora_WT.png"

ren_wt_r10k_TADs_noC_ren_rep2vs1 = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_WT_rep2_vs_rep1.png"
ren_wt_r10k_TADs_noC_ren_iaa_vs_wt = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.Ren_IAA_vs_WT.png"
ren_wt_r10k_TADs_noC_wn_bpk25_vs_ren_wt = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.WN_BPK25_vs_Ren_WT.png"

# 打开 PPT 并插入图片
my_ppt = Presentation('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')
# slide4
slide4 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
# pic = slide.shapes.add_picture(png_files[pi-1], left, top, width, height)
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_nora_rep2vs1, Cm(0.53), Cm(0), Cm(7.14), Cm(7.14))
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_nora_iaa_vs_wt, Cm(9.08), Cm(0), Cm(7.14), Cm(7.14))
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_wn_bpk25_vs_nora_wt, Cm(17.73), Cm(0), Cm(7.14), Cm(7.14))
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_ren_rep2vs1, Cm(0.53), Cm(7.14), Cm(7.14), Cm(7.14))
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_ren_iaa_vs_wt, Cm(9.08), Cm(7.14), Cm(7.14), Cm(7.14))
slide4.shapes.add_picture(ren_wt_r10k_TADs_noC_wn_bpk25_vs_ren_wt, Cm(17.73), Cm(7.14), Cm(7.14), Cm(7.14))
# 插入文本注释
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_nora_rep2vs1", Cm(0.53), Cm(0), Cm(7.14), Cm(0.5))
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_nora_iaa_vs_wt", Cm(9.08), Cm(0), Cm(7.14), Cm(0.5))
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_wn_bpk25_vs_nora_wt", Cm(17.73), Cm(0), Cm(7.14), Cm(0.5))
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_ren_rep2vs1", Cm(0.53), Cm(7.14), Cm(7.14), Cm(0.5))
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_ren_iaa_vs_wt", Cm(9.08), Cm(7.14), Cm(7.14), Cm(0.5))
add_text_anno(slide4, "ren_wt_r10k_TADs_noC_wn_bpk25_vs_ren_wt", Cm(17.73), Cm(7.14), Cm(7.14), Cm(0.5))

ren_wt_r10k_TADs_noC_nora_wn_3comparation = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Nora_WN_3comparation.exp_row.png"
ren_wt_r10k_TADs_noC_ren_wn_3comparation = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_Ren_WN_3comparation.exp_row.png"
ren_wt_r10k_TADs_noC_nora_wn_ren_6comparation = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_noClassified.merge_6comparation.exp_row.png"
# slide5
slide5 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
# pic = slide.shapes.add_picture(png_files[pi-1], left, top, width, height)
slide5.shapes.add_picture(ren_wt_r10k_TADs_noC_nora_wn_3comparation, Cm(2.84), Cm(0.57), Cm(19.72), Cm(6.57))
slide5.shapes.add_picture(ren_wt_r10k_TADs_noC_ren_wn_3comparation, Cm(2.84), Cm(7.72), Cm(19.72), Cm(6.57))
# 插入文本注释
add_text_anno(slide5, "ren_wt_r10k_TADs_noC_nora_wn_3comparation", Cm(0), Cm(0.05), Cm(12.7), Cm(0.5))
add_text_anno(slide5, "ren_wt_r10k_TADs_noC_ren_wn_3comparation", Cm(0), Cm(7.14), Cm(12.7), Cm(0.5))

# slide6
slide6 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide6.shapes.add_picture(ren_wt_r10k_TADs_noC_nora_wn_ren_6comparation, Cm(2.46), Cm(0.64), Cm(20.48), Cm(13.64))
# 插入文本注释
add_text_anno(slide6, "ren_wt_r10k_TADs_noC_nora_wn_ren_6comparation", Cm(0), Cm(0.05), Cm(12.7), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %% [markdown]
# ## add TADs_lenQ4c

# %%
# 打开 PPT 并插入图片
my_ppt = Presentation('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')
# slide7
slide7 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])

ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep1_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep1.png"
ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep2_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2.png"
# slide8
slide8 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
# pic = slide.shapes.add_picture(png_files[pi-1], left, top, width, height)
slide8.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep1_png, Cm(0), Cm(1.31), Cm(25.4), Cm(5.08))
slide8.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep2_png, Cm(0), Cm(7.9), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide8, "ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep1_png", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide8, "ren_wt_r10k_TADs_lenQ4c_Nora_WT_rep2_png", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep1_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep1.png"
ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep2_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2.png"
# slide9
slide9 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
# pic = slide.shapes.add_picture(png_files[pi-1], left, top, width, height)
slide9.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep1_png, Cm(0), Cm(1.31), Cm(25.4), Cm(5.08))
slide9.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep2_png, Cm(0), Cm(7.9), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide9, "ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep1_png", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide9, "ren_wt_r10k_TADs_lenQ4c_Ren_WT_rep2_png", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Nora_WT_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT.png"
ren_wt_r10k_TADs_lenQ4c_Nora_IAA_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA.png"
# slide10
slide10 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide10.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WT_png, Cm(0), Cm(1.31), Cm(25.4), Cm(5.08))
slide10.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_IAA_png, Cm(0), Cm(7.9), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide10, "ren_wt_r10k_TADs_lenQ4c_Nora_WT_png", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide10, "ren_wt_r10k_TADs_lenQ4c_Nora_IAA_png", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_WN_BPK25_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25.png"
# slide11
slide11 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide11.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_WN_BPK25_png, Cm(0), Cm(1.31), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide11, "ren_wt_r10k_TADs_lenQ4c_WN_BPK25_png", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Ren_WT_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT.png"
ren_wt_r10k_TADs_lenQ4c_Ren_IAA_png = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA.png"
# slide12
slide12 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide12.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_WT_png, Cm(0), Cm(1.31), Cm(25.4), Cm(5.08))
slide12.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_IAA_png, Cm(0), Cm(7.9), Cm(25.4), Cm(5.08))
# 插入文本注释
add_text_anno(slide12, "ren_wt_r10k_TADs_lenQ4c_Ren_WT_png", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide12, "ren_wt_r10k_TADs_lenQ4c_Ren_IAA_png", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %%
# 打开 PPT 并插入图片
my_ppt = Presentation('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

ren_wt_r10k_TADs_lenQ4c_Nora_WN_row = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_row.png"
# slide13
slide13 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide13.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WN_row, Cm(0.79), Cm(0), Cm(23.81), Cm(14.29))
add_text_anno(slide13, "ren_wt_r10k_TADs_lenQ4c_Nora_WN_row", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Ren_WN_row = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_row.png"
# slide14
slide14 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide14.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_WN_row, Cm(0.79), Cm(0), Cm(23.81), Cm(14.29))
add_text_anno(slide14, "ren_wt_r10k_TADs_lenQ4c_Ren_WN_row", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Nora_WN_col = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN.exp_col.png"
ren_wt_r10k_TADs_lenQ4c_Ren_WN_col = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WN.exp_col.png"
# slide15
slide15 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
# PPT 页面指定区域插入图片
slide15.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WN_col, Cm(2.21), Cm(0), Cm(8.57), Cm(14.29))
slide15.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_WN_col, Cm(14.62), Cm(0), Cm(8.57), Cm(14.29))
# 插入文本注释
add_text_anno(slide15, "ren_wt_r10k_TADs_lenQ4c_Nora_WN_col", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide15, "ren_wt_r10k_TADs_lenQ4c_Ren_WN_col", Cm(14.55), Cm(0.05), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_row = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_row.png"
ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_col = "coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WN_Ren.exp_col.png"
# slide16
slide16 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide16.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_row, Cm(0), Cm(0.79), Cm(12.7), Cm(12.7))
slide16.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_col, Cm(12.7), Cm(0.79), Cm(12.7), Cm(12.7))
add_text_anno(slide16, "ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_row", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide16, "ren_wt_r10k_TADs_lenQ4c_Nora_WN_Ren_col", Cm(14.55), Cm(0.05), Cm(10.85), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %%
# 打开 PPT 并插入图片
my_ppt = Presentation('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

ren_wt_r10k_TADs_lenQ4c_Nora_rep2vs1 = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_WT_rep2_vs_rep1.png"
ren_wt_r10k_TADs_lenQ4c_Ren_rep2vs1 = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_WT_rep2_vs_rep1.png"
# slide17
slide17 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide17.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_rep2vs1, Cm(0), Cm(1.05), Cm(25.4), Cm(5.08))
slide17.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_rep2vs1, Cm(0), Cm(8.2), Cm(25.4), Cm(5.08))
add_text_anno(slide17, "ren_wt_r10k_TADs_lenQ4c_Nora_rep2vs1", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide17, "ren_wt_r10k_TADs_lenQ4c_Ren_rep2vs1", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_Nora_IAA_vs_WT = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Nora_IAA_vs_WT.png"
ren_wt_r10k_TADs_lenQ4c_Ren_IAA_vs_WT = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.Ren_IAA_vs_WT.png"
# slide18
slide18 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide18.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Nora_IAA_vs_WT, Cm(0), Cm(1.05), Cm(25.4), Cm(5.08))
slide18.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_Ren_IAA_vs_WT, Cm(0), Cm(8.2), Cm(25.4), Cm(5.08))
add_text_anno(slide18, "ren_wt_r10k_TADs_lenQ4c_Nora_IAA_vs_WT", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide18, "ren_wt_r10k_TADs_lenQ4c_Ren_IAA_vs_WT", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Nora_WT = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Nora_WT.png"
ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Ren_WT = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.WN_BPK25_vs_Ren_WT.png"
# slide19
slide19 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide19.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Nora_WT, Cm(0), Cm(1.05), Cm(25.4), Cm(5.08))
slide19.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Ren_WT, Cm(0), Cm(8.2), Cm(25.4), Cm(5.08))
add_text_anno(slide19, "ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Nora_WT", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide19, "ren_wt_r10k_TADs_lenQ4c_WN_BPK25_vs_Ren_WT", Cm(0), Cm(7.15), Cm(10.85), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %%
# 打开 PPT 并插入图片
my_ppt = Presentation('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_col = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Nora_WN_3comparation.exp_col.png"
ren_wt_r10k_TADs_lenQ4c_divide_Ren_WN_col = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_Ren_WN_3comparation.exp_col.png"
# slide20
slide20 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide20.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_col, Cm(2.26), Cm(0), Cm(8.57), Cm(14.29))
slide20.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_divide_Ren_WN_col, Cm(14.88), Cm(0), Cm(8.57), Cm(14.29))
add_text_anno(slide20, "ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_col", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))
add_text_anno(slide20, "ren_wt_r10k_TADs_lenQ4c_divide_Ren_WN_col", Cm(14.55), Cm(0.05), Cm(10.85), Cm(0.5))

ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_Ren = "coolpuppy_pileup_divide_plot_for_Ren_WT_r10k_TADs_lenQ4c.merge_6comparation.exp_col.png"
# slide21
slide21 = my_ppt.slides.add_slide(my_ppt.slide_layouts[6])
slide21.shapes.add_picture(ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_Ren, Cm(4.13), Cm(0), Cm(17.15), Cm(14.29))
add_text_anno(slide21, "ren_wt_r10k_TADs_lenQ4c_divide_Nora_WN_Ren", Cm(0), Cm(0.05), Cm(10.85), Cm(0.5))

# 保存 PPT
my_ppt.save('8.11_coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs.use_Nora_WN_Ren_mcool.r10k.pptx')

# %% [markdown]
# # 移动相关结果到特定文件夹

# %%
# %%bash
# mkdir coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_use_e5_r10k
# mv coolpuppy_*for_Ren_WT_r10k_TADs*.pdf ./coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_use_e5_r10k
# mv coolpuppy_*for_Ren_WT_r10k_TADs*.png ./coolpuppy_pileup_plot_for_Ren_WT_r10k_TADs_use_e5_r10k
